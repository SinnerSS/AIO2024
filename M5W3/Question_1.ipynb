# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
random_state = 59
np.random.seed(random_state)
torch.manual_seed(random_state)
if torch.cuda.is_available():
    torch.cuda.manual_seed(random_state)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
dataset_path = 'Auto_MPG_data.csv'
dataset = pd.read_csv(dataset_path)

# %%
X = dataset.drop(columns='MPG').values
y = dataset['MPG'].values

# %%
val_size = 0.2
test_size = 0.125
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split (
    X, y,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)
X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
normalizer = StandardScaler()
X_train = normalizer.fit_transform(X_train)
X_val = normalizer.transform(X_val)
X_test = normalizer.transform(X_test)

X_train = torch.tensor(X_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
batch_size = 32
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_val, y_val)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.linear2 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

    def forward(self, x):
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)
        x = F.relu(x)
        out = self.output(x)

        return out.squeeze(1)

# %%
input_dims = X_train.shape[1]
output_dims = 1
hidden_dims = 64

model = MLP(input_dims=input_dims, hidden_dims=hidden_dims, output_dims=output_dims)

# %%
lr = 1e-2
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %%
def r_squared(y_true, y_pred):
    y_true = torch.Tensor(y_true).to(device)
    y_pred = torch.Tensor(y_pred).to(device)
    mean_true = torch.mean(y_true)
    ss_tot = torch.sum((y_true - mean_true) ** 2)
    ss_res = torch.sum((y_true - y_pred) ** 2)
    r2 = 1 - ss_res / ss_tot

    return r2

# %%
epochs = 100
train_losses = []
val_losses = []
train_r2 = []
val_r2 = []

for epoch in range(epochs):
    train_loss = 0.0
    train_target = []
    val_target = []
    train_predict = []
    val_predict = []
    model.train()
    for X_samples, y_samples in train_loader:
        X_samples = X_samples.to(device)
        y_samples = y_samples.to(device)
        optimizer.zero_grad()
        outputs = model(X_samples)
        train_predict += outputs.tolist()
        train_target += y_samples.tolist()
        loss = criterion(outputs, y_samples)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    train_r2.append(r_squared(train_target, train_predict))
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for X_samples, y_samples in val_loader:
            X_samples = X_samples.to(device)
            y_samples = y_samples.to(device)
            outputs = model(X_samples)
            val_predict += outputs.tolist()
            val_target += y_samples.tolist()
            loss = criterion(outputs, y_samples)
            val_loss += loss.item()
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_r2.append(r_squared(val_target, val_predict))
    print(f'\nEPOCH {epoch + 1}:\tTraining loss: {train_loss:.3f}\tValidation loss: {val_loss:.3f}')
# Out:
# EPOCH 1:	Training loss: 282.769	Validation loss: 88.672
#
# EPOCH 2:	Training loss: 137.672	Validation loss: 72.346
#
# EPOCH 3:	Training loss: 70.983	Validation loss: 19.099
#
# EPOCH 4:	Training loss: 25.166	Validation loss: 199.086
#
# EPOCH 5:	Training loss: 96.502	Validation loss: 19.986
#
# EPOCH 6:	Training loss: 17.649	Validation loss: 10.965
#
# EPOCH 7:	Training loss: 19.022	Validation loss: 13.019
#
# EPOCH 8:	Training loss: 36.947	Validation loss: 32.491
#
# EPOCH 9:	Training loss: 18.232	Validation loss: 31.316
#
# EPOCH 10:	Training loss: 19.360	Validation loss: 45.363
#
# EPOCH 11:	Training loss: 29.778	Validation loss: 19.422
#
# EPOCH 12:	Training loss: 9.627	Validation loss: 6.098
#
# EPOCH 13:	Training loss: 15.039	Validation loss: 15.549
#
# EPOCH 14:	Training loss: 11.969	Validation loss: 11.563
#
# EPOCH 15:	Training loss: 13.494	Validation loss: 8.119
#
# EPOCH 16:	Training loss: 10.557	Validation loss: 18.859
#
# EPOCH 17:	Training loss: 11.932	Validation loss: 14.607
#
# EPOCH 18:	Training loss: 15.213	Validation loss: 12.507
#
# EPOCH 19:	Training loss: 14.246	Validation loss: 5.336
#
# EPOCH 20:	Training loss: 7.261	Validation loss: 5.062
#
# EPOCH 21:	Training loss: 8.504	Validation loss: 4.767
#
# EPOCH 22:	Training loss: 6.168	Validation loss: 5.265
#
# EPOCH 23:	Training loss: 9.991	Validation loss: 50.747
#
# EPOCH 24:	Training loss: 10.599	Validation loss: 14.877
#
# EPOCH 25:	Training loss: 8.930	Validation loss: 8.750
#
# EPOCH 26:	Training loss: 9.627	Validation loss: 6.963
#
# EPOCH 27:	Training loss: 6.231	Validation loss: 6.471
#
# EPOCH 28:	Training loss: 10.166	Validation loss: 4.917
#
# EPOCH 29:	Training loss: 6.526	Validation loss: 12.734
#
# EPOCH 30:	Training loss: 18.511	Validation loss: 4.693
#
# EPOCH 31:	Training loss: 7.939	Validation loss: 6.220
#
# EPOCH 32:	Training loss: 6.819	Validation loss: 6.069
#
# EPOCH 33:	Training loss: 7.227	Validation loss: 4.518
#
# EPOCH 34:	Training loss: 6.974	Validation loss: 6.050
#
# EPOCH 35:	Training loss: 7.599	Validation loss: 6.654
#
# EPOCH 36:	Training loss: 5.911	Validation loss: 6.228
#
# EPOCH 37:	Training loss: 6.136	Validation loss: 5.971
#
# EPOCH 38:	Training loss: 7.137	Validation loss: 9.802
#
# EPOCH 39:	Training loss: 7.827	Validation loss: 14.105
#
# EPOCH 40:	Training loss: 7.237	Validation loss: 5.655
#
# EPOCH 41:	Training loss: 5.766	Validation loss: 21.660
#
# EPOCH 42:	Training loss: 7.966	Validation loss: 5.428
#
# EPOCH 43:	Training loss: 7.032	Validation loss: 24.804
#
# EPOCH 44:	Training loss: 9.209	Validation loss: 11.483
#
# EPOCH 45:	Training loss: 6.632	Validation loss: 4.899
#
# EPOCH 46:	Training loss: 8.145	Validation loss: 7.131
#
# EPOCH 47:	Training loss: 6.238	Validation loss: 6.448
#
# EPOCH 48:	Training loss: 5.244	Validation loss: 6.442
#
# EPOCH 49:	Training loss: 6.603	Validation loss: 10.324
#
# EPOCH 50:	Training loss: 6.415	Validation loss: 11.010
#
# EPOCH 51:	Training loss: 7.902	Validation loss: 7.869
#
# EPOCH 52:	Training loss: 10.994	Validation loss: 5.329
#
# EPOCH 53:	Training loss: 7.199	Validation loss: 4.989
#
# EPOCH 54:	Training loss: 6.449	Validation loss: 5.331
#
# EPOCH 55:	Training loss: 5.362	Validation loss: 5.219
#
# EPOCH 56:	Training loss: 5.486	Validation loss: 5.930
#
# EPOCH 57:	Training loss: 7.247	Validation loss: 6.826
#
# EPOCH 58:	Training loss: 6.539	Validation loss: 17.859
#
# EPOCH 59:	Training loss: 7.276	Validation loss: 7.458
#
# EPOCH 60:	Training loss: 5.500	Validation loss: 4.783
#
# EPOCH 61:	Training loss: 5.463	Validation loss: 8.329
#
# EPOCH 62:	Training loss: 10.220	Validation loss: 4.651
#
# EPOCH 63:	Training loss: 6.509	Validation loss: 13.528
#
# EPOCH 64:	Training loss: 6.105	Validation loss: 6.233
#
# EPOCH 65:	Training loss: 8.238	Validation loss: 5.253
#
# EPOCH 66:	Training loss: 5.197	Validation loss: 5.216
#
# EPOCH 67:	Training loss: 5.957	Validation loss: 5.941
#
# EPOCH 68:	Training loss: 10.071	Validation loss: 7.394
#
# EPOCH 69:	Training loss: 6.714	Validation loss: 9.165
#
# EPOCH 70:	Training loss: 6.161	Validation loss: 5.295
#
# EPOCH 71:	Training loss: 5.225	Validation loss: 4.799
#
# EPOCH 72:	Training loss: 5.936	Validation loss: 8.578
#
# EPOCH 73:	Training loss: 6.372	Validation loss: 9.673
#
# EPOCH 74:	Training loss: 6.145	Validation loss: 5.215
#
# EPOCH 75:	Training loss: 5.399	Validation loss: 17.118
#
# EPOCH 76:	Training loss: 7.509	Validation loss: 20.971
#
# EPOCH 77:	Training loss: 11.074	Validation loss: 7.097
#
# EPOCH 78:	Training loss: 6.742	Validation loss: 5.387
#
# EPOCH 79:	Training loss: 5.879	Validation loss: 11.081
#
# EPOCH 80:	Training loss: 8.060	Validation loss: 5.712
#
# EPOCH 81:	Training loss: 10.408	Validation loss: 6.299
#
# EPOCH 82:	Training loss: 5.660	Validation loss: 5.092
#
# EPOCH 83:	Training loss: 5.469	Validation loss: 8.355
#
# EPOCH 84:	Training loss: 5.238	Validation loss: 5.048
#
# EPOCH 85:	Training loss: 4.739	Validation loss: 6.217
#
# EPOCH 86:	Training loss: 4.640	Validation loss: 6.155
#
# EPOCH 87:	Training loss: 5.103	Validation loss: 7.895
#
# EPOCH 88:	Training loss: 5.264	Validation loss: 4.952
#
# EPOCH 89:	Training loss: 4.794	Validation loss: 5.240
#
# EPOCH 90:	Training loss: 6.392	Validation loss: 5.526
#
# EPOCH 91:	Training loss: 5.107	Validation loss: 7.229
#
# EPOCH 92:	Training loss: 6.808	Validation loss: 5.449
#
# EPOCH 93:	Training loss: 6.086	Validation loss: 5.416
#
# EPOCH 94:	Training loss: 9.878	Validation loss: 7.645
#
# EPOCH 95:	Training loss: 6.415	Validation loss: 5.897
#
# EPOCH 96:	Training loss: 8.107	Validation loss: 19.305
#
# EPOCH 97:	Training loss: 6.833	Validation loss: 11.730
#
# EPOCH 98:	Training loss: 7.214	Validation loss: 7.584
#
# EPOCH 99:	Training loss: 6.099	Validation loss: 4.847
#
# EPOCH 100:	Training loss: 5.812	Validation loss: 4.858

# %%
model.eval()
with torch.no_grad():
    y_hat = model(X_test)
    test_set_r2 = r_squared(y_hat, y_test)
    print('Evaluation on test set:')
    print(f'R2: {test_set_r2}')
# Out:
# Evaluation on test set:
# R2: 0.8330833315849304
